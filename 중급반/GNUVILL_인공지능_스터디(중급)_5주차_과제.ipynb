# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeong-kim-git/GNUVILL_AI/blob/main/GNUVILL_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EC%8A%A4%ED%84%B0%EB%94%94(%EC%A4%91%EA%B8%89)_5%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GNUVILL 인공지능 스터디(중급) 5주차 과제
#
# 주제: 다중 선형 회귀 분석을 통한 주식 데이터 분석

# %% [markdown]
# ## 1. 라이브러리
#
#
#
# * **sklearn**: 회귀 분석을 돕는 라이브러리
# * **linear_model**: sklearn 내 선형 모형을 토대로 선형 회귀 분석을 도움,

# %%
# 코드 작성
# np라는 이름으로 numpy import
# pd라는 이름으로 pandas import
# plt라는 이름으로 matplotlib 중 pyplot import
# sklearn의 linear_model에서 LinearRegression import!

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
# 다운로드한 stock.csv 업로드!
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e0f4559-8505-4e26-82c0-4ef93a2cb17b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e0f4559-8505-4e26-82c0-4ef93a2cb17b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock.csv to stock.csv

# %%
import io
# 코드 작성: stock라는 변수에 stock.csv 읽어오기(io 활용)
stock = #pd를 사용해 csv 파일 읽기(io.BytesIO(uploaded['stock.csv']))

# %%
stock.head(5)
# Out:
#          Date        Open        High  ...       Close   Adj Close    Volume
# 0  2020-01-27  161.149994  163.380005  ...  162.279999  161.837952  32078100
# 1  2020-01-28  163.779999  165.759995  ...  165.460007  165.009308  24899900
# 2  2020-01-29  167.839996  168.750000  ...  168.039993  167.582260  34754500
# 3  2020-01-30  174.050003  174.050003  ...  172.779999  172.309357  51597500
# 4  2020-01-31  172.210007  172.399994  ...  170.229996  169.766296  36142700
#
# [5 rows x 7 columns]

# %%
import datetime as ddt #Date열을 숫자(그냥 정수)로 바꾸기
stock['Date']=pd.to_datetime(stock['Date'])
stock['Date']=stock['Date'].map(ddt.datetime.toordinal)

# %% [markdown]
# ## 3. 변수 X, Y 정하기

# %%
# 독립변수 X에 stock의 'Date','Open','High','Low','Close','Adj Close'를 DataFrame 형태로 저장하기
# 종속변수 Y에 stock의 'Volume' Series 형태로 저장하기

# %% [markdown]
# ## 4. 선형 회귀 분석
#
#
# *   **fit(X, Y)**: 모델에 데이터 X, Y를 맞추는 함수

# %%
# reg라는 변수에 LinearRegression 초기화하기
# reg에 X, Y fit시키기

# %%
# Intercept라는 변수에 reg의 절편 저장하기
# Coefficient라는 변수에 reg의 계수 저장하기
# 변수 이름이 곧 힌트!

# %% [markdown]
# ## 5. 다중 선형 회귀 분석

# %%
import statsmodels.api as ssm # 통계 분석 라이브러리

# %% [markdown]
# *   **.add_constant**: 상수항 결합을 위한 statsmodel의 함수
# * **.OLS(X, Y)**: 잔차제곱합을 최소화하는 가중치 벡터를 행렬 미분으로 구하는 방법
# * **.fit()**: 모델에 맞게 꽉 맞춰주는 함수
# * **.summary()**: 회귀 분석의 결과 출력

# %%
# X라는 변수에 X의 상수값 넣기
# model이라는 변수에 Y, X fit!
# predictions이라는 변수에 model을 요약한 내용을 저장
# predictions 출력
