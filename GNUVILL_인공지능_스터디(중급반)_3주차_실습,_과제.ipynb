# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeong-kim-git/GNUVILL_AI/blob/main/GNUVILL_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EC%8A%A4%ED%84%B0%EB%94%94(%EC%A4%91%EA%B8%89%EB%B0%98)_3%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5%2C_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tensorflow
#
# Tensorflow는 다음과 같은 처리를 반복한다.
#
# *   텐서노트와 엣지로 이루어진 그래프를 빌드한다.
# *   세션을 통해 그래프를 실행시킨다.(Session.run())
# *   실행 결과를 기반으로 텐서플로우는 다시 그래프를 업데이트시키기 위해 W(가중치) 값과 b(바이어스) 값을 구한다.
#
# 참고하면 좋은 자료: https://tensorflowkorea.gitbooks.io/tensorflow-kr/content/g3doc/how_tos/variables/

# %%
# Tensorflow 설치 후 import

# !pip install -q tensorflow-gpu==2.0.0-rc1
import tensorflow as tf
# Out:
#      |████████████████████████████████| 380.5MB 36kB/s
#      |████████████████████████████████| 501kB 50.6MB/s
#      |████████████████████████████████| 4.3MB 44.2MB/s
#      |████████████████████████████████| 51kB 6.1MB/s

# %%
# Tensorflow 간단 실습

# %% [markdown]
# ---
# # 경사 하강법 간단 실습

# %% [markdown]
# ##1. 데이터 셋

# %%
# 데이터는 임의로 설정
x_data = []
y_data = []

# %% [markdown]
# ##2. W, X, y 정의

# %% [markdown]
# 선형 회귀 방정식 y = Wx + b에서 W, X, y를 정의한다. 이때 아래의 내용을 참고하자.
# *   tf.Variable: 변수 생성
# *   tf.placeholder: 변수의 타입을 이미 설정해놓고 필요한 변수를 나중에 받아 실행

# %%
# 코드 작성

# %% [markdown]
# ##3. 경사 하강법 구현

# %% [markdown]
# 이후 경사 하강법을 구현한다. 마찬가지로 아래를 참고하자.
# *   tf.reduce_mean: 전체 평균을 구한다
# *   tf.square: 제곱을 계산

# %% [markdown]
# ##4. 모델 학습

# %%
sess.run(tf.global_variables_initializer())

for step in range(21):
  feed_dict = {x:x_data, y:y_data}
  sess.run(update, feed_dict)
  print(step, sess.run[cost, w], feed_dict())

# %% [markdown]
# ---
# #과제: weight 값에 따른 cost 값의 변화 시각화
#
# weight값에 변화를 주면서 cost가 낮아지는 방향으로 update가 된다는 것을 알게 되었다. 그렇다면, weight값이 변화함에 따라서 cost가 어떻게 변화하는지 시각화 그래프를 그려서 확인해 보자.

# %%
# 빈칸1. matplotlib.pyplot plt로 import

x = [1, 3, 5]
y = [10, 28, 40]

# 빈칸2. weight : placeholder로 선언
hf = x*w # b는 무시하고 w에 의한 변화만 확인

# 빈칸3. loss 변수에 제곱한 값의 전체 평균 대입(hint: 텐서플로우 활용!)

w_history, c_history = [], []

for i in range(-100, 301, 1):
    curr_w = i * 0.1
    loss_v = sess.run(loss, {w:curr_w})
    # weight의 갑소가 weight값에 따른 cost값 저장
    w_history.append(curr_w)
    c_history.append(loss_v)

# 빈칸4. w_history, c_history의 그래프 출력
