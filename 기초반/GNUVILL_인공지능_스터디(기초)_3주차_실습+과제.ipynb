# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeong-kim-git/GNUVILL_AI/blob/main/GNUVILL_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EC%8A%A4%ED%84%B0%EB%94%94(%EA%B8%B0%EC%B4%88)_3%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5%2B%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GNUVILL 인공지능 스터디(기초) 3주차 과제
#
# 선형회귀 복습 + 경사하강법 실습
# : 당뇨병 환자의 데이터를 토대로 선형 회귀를 진행해보고 경사 하강법도 적용해봅시다!

# %% [markdown]
# ---
#
# ##1. 라이브러리
#
# *  **matplotlib**: 시각화 관련 함수들을 모아놓은 모듈(그래프를 그려준다!)
#
#   자세한 정보는 https://matplotlib.org/ 참고

# %% [markdown]
# ##2. 데이터셋 준비

# %% [markdown]
# *   **sklearn.datasets**: 대표적인 sample dataset들을 제공하고 쉽게 다운로드 받을 수 있음.
#
#   ex) 아이리스, 보스턴 집값 데이터, 당뇨병 환자 데이터 등
#
#   https://teddylee777.github.io/scikit-learn/Sklearn-dataset-%EB%AA%A8%EB%93%88%EC%9D%84-%ED%99%9C%EC%9A%A9%ED%95%98%EC%97%AC-dataset%EB%A1%9C%EB%94%A9%ED%95%98%EA%B8%B0
# *   **load_diabetes**: 당뇨병 환자 데이터셋 준비

# %%
from sklearn.datasets import load_diabetes

# %% [markdown]
# ## 3. 입력과 타깃 데이터의 크기 확인

# %% [markdown]
# data는 442 * 10 크기의 2차원 배열, target은 442개의 요소를 가진 1차원 배열
#
# 행은 샘플(sample), 열은 샘플의 특성(feature) 의미
#
#
#
# ---
#
#
# *  **샘플**: 당뇨병 환자에 대한 특성으로 이루어진 데이터 1세트
# *   **특성**: 당뇨병 환자들의 여러 특징 ex) 키, 몸무게, 혈압, 혈당 등
#
# ---
#
#
# *   **.shape**: 행렬의 차원, 크기 확인

# %% [markdown]
# ## 4. 시각화(산포도 그리기)

# %% [markdown]
# *   **plt.scatter**: 산포도 그리기
# *   **plt.xlabel("  ")**: x축에 괄호 안에 들어가는 문자, 또는 문자열로 이름을 붙임
# * **plt.ylabel("  ")**: y축에 괄호 안에 들어가는 문자, 또는 문자열로 이름을 붙임

# %%
# 그래프 그리기

# %% [markdown]
# ## 5. 경사 하강법

# %% [markdown]
# ### 1) 가중치 초기화

# %%
# W, b를 모두 1.0으로 초기화

# %%
# 입력 x와 타깃 y
plt.scatter(x,y)

# 코드 작성: 선형 회귀 방정식 y_hat에 대입하기
plt.plot(x, y_hat)
plt.show()
# Out:
# 160.79849903436158

# %% [markdown]
# ### 2) 예측값 구하기

# %%
def forpass(x):
  # 코드 작성: 선형 회귀 방정식 y_hat에 대입하기
  return y_hat

# %% [markdown]
# ### 3) 가중치 업데이트

# %%
def backprop(x, err):
  # 코드 작성: w_grad라는 변수에 x에 err을 곱하여 대입
  # 코드 작성: b_grad라는 변수에 1에 err을 곱하여 대입
  return w_grad, b_grad

# %% [markdown]
# ### 4) 모든 샘플과 에포크에 대해 반복

# %%
def fit(x, y, epoch = 100):
  global W
  global b
  # 코드 작성: for문 사용 -> 만약 i가 epoch 안에 있다면:
    for x_i, y_i in zip(x,y):
      # 코드 작성: y_hat는 x_i를 forpass 함수에 대입한 값
      # 코드 작성: err는 y_i에서 y_hat를 뺀 값에 마이너스한 값
      w_grad, b_grad = backprop(x_i, err)
      w -= w_grad
      b -= b_grad

# %% [markdown]
# ### 5) 알고리즘 실행 후 결과 그래프 확인

# %%
fit(x, y)

# %%
# 입력 x와 타깃 y
plt.scatter(x,y)

# 코드 작성: 선형 회귀 방정식 y_hat에 대입하기
plt.plot(x, y_hat)
plt.show()
